# %%
import re
import os
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
def get_concepts_from_file(file_path,file_name,source):
    
    list_of_concepts = list()
    
    file = open(file_path, 'r',encoding="utf8",errors = 'ignore') 
    Lines = file.readlines() 
    for line in Lines: 
        entry = line.strip()
        regular_exp_con = 'c="(.*)" ([0-9]*):([0-9]*) [0-9]*:([0-9]*)\|\|t="(.*)"'
        pattern_search = re.search(regular_exp_con, entry, re.IGNORECASE)

        if pattern_search:
            concept_dict = dict()
            concept_dict['source'] = source
            concept_dict['file_name'] = file_name 
            concept_dict['text'] = pattern_search.group(1)
            concept_dict['line_number'] = int(pattern_search.group(2))
            concept_dict['begin_word_num'] = int(pattern_search.group(3))
            concept_dict['end_word_num'] = int(pattern_search.group(4))
            concept_dict['concept_type'] = pattern_search.group(5)
            list_of_concepts.append(concept_dict)
    
    return list_of_concepts

# %%
data_file_path = os.path.dirname(os.getcwd()) + r'\Data\concept_assertion_relation_training_data' 
beth_file_path = data_file_path + r'\beth'
partners_file_path = data_file_path + r'\partners'

list_of_all_concepts = list()

for file in os.listdir(beth_file_path+r'\concept'):
    file_path = os.path.join(beth_file_path+r'\concept', file)
    list_of_all_concepts.extend(get_concepts_from_file(file_path,file.strip(".con"),'beth'))

for file in os.listdir(partners_file_path+r'\concept'):
    file_path = os.path.join(partners_file_path+r'\concept', file)
    list_of_all_concepts.extend(get_concepts_from_file(file_path,file.strip(".con"),'partners'))

# %%
concept_df = pd.DataFrame(list_of_all_concepts)

# %%
concept_df.head()
# Out:
#   source   file_name                       text  line_number  begin_word_num  \
# 0   beth  record-105   left basilar atelectasis           55               6
# 1   beth  record-105             ventral hernia          143               1
# 2   beth  record-105                        htn           26               0
# 3   beth  record-105  spontaneous echo contrast           68               1
# 4   beth  record-105                       cath           21               0
#
#    end_word_num concept_type
# 0             8      problem
# 1             2      problem
# 2             0      problem
# 3             3      problem
# 4             0         test

# %%
concept_df.groupby(['concept_type']).size()
# Out:
# concept_type
# problem      7073
# test         4608
# treatment    4844
# dtype: int64

# %%
def get_assertions_from_file(file_path,file_name,source):
    
    list_of_assertions = list()
    
    file = open(file_path, 'r',encoding="utf8",errors = 'ignore') 
    Lines = file.readlines() 
    
    for line in Lines: 
        entry = line.strip()
        regular_exp_con = 'c="(.*)" ([0-9]*):([0-9]*) [0-9]*:([0-9]*)\|\|t=".*"\|\|a="(.*)"'
        pattern_search = re.search(regular_exp_con, entry, re.IGNORECASE)

        if pattern_search:
            assertion_dict = dict()
            assertion_dict['source'] = source
            assertion_dict['file_name'] = file_name 
            assertion_dict['text'] = pattern_search.group(1)
            assertion_dict['line_number'] = int(pattern_search.group(2))
            assertion_dict['begin_word_num'] = int(pattern_search.group(3))
            assertion_dict['end_word_num'] = int(pattern_search.group(4))
            assertion_dict['assertion_type'] = pattern_search.group(5)
            list_of_assertions.append(assertion_dict)
    
    return list_of_assertions

# %%
list_of_all_assertions = list()

for file in os.listdir(beth_file_path+r'\ast'):
    file_path = os.path.join(beth_file_path+r'\ast', file)
    list_of_all_assertions.extend(get_assertions_from_file(file_path,file,'beth'))

for file in os.listdir(partners_file_path+r'\ast'):
    file_path = os.path.join(partners_file_path+r'\ast', file)
    list_of_all_assertions.extend(get_assertions_from_file(file_path,file,'partners'))

# %%
assertion_df = pd.DataFrame(list_of_all_assertions)

# %%
assertion_df.head()
# Out:
#   source       file_name                       text  line_number  \
# 0   beth  record-105.ast   left basilar atelectasis           55
# 1   beth  record-105.ast             ventral hernia          143
# 2   beth  record-105.ast                        htn           26
# 3   beth  record-105.ast  spontaneous echo contrast           68
# 4   beth  record-105.ast              80% lm lesion           21
#
#    begin_word_num  end_word_num assertion_type
# 0               6             8        present
# 1               1             2        present
# 2               0             0        present
# 3               1             3         absent
# 4               6             8        present

# %%
assertion_df.groupby(['assertion_type']).size()
# Out:
# assertion_type
# absent                          1596
# associated_with_someone_else      89
# conditional                       73
# hypothetical                     382
# possible                         309
# present                         4624
# dtype: int64

# %%
def get_relations_from_file(file_path,file_name,source):
    
    list_of_relations = list()
    
    file = open(file_path, 'r',encoding="utf8",errors = 'ignore') 
    Lines = file.readlines() 
    
    for line in Lines: 
        entry = line.strip()
        regular_exp_con = 'c="(.*)" ([0-9]*):([0-9]*) [0-9]*:([0-9]*)\|\|r="(.*)"\|\|c="(.*)" ([0-9]*):([0-9]*) [0-9]*:([0-9]*)'
        pattern_search = re.search(regular_exp_con, entry, re.IGNORECASE)

        if pattern_search:
            relation_dict = dict()
            relation_dict['source'] = source
            relation_dict['file_name'] = file_name 
            relation_dict['from_text'] = pattern_search.group(1)
            relation_dict['from_line_number'] = int(pattern_search.group(2))
            relation_dict['from_begin_word_num'] = int(pattern_search.group(3))
            relation_dict['from_end_word_num'] = int(pattern_search.group(4))
            relation_dict['relation_type'] = pattern_search.group(5)
            relation_dict['to_text'] = pattern_search.group(6)
            relation_dict['to_line_number'] = int(pattern_search.group(7))
            relation_dict['to_begin_word_num'] = int(pattern_search.group(8))
            relation_dict['to_end_word_num'] = int(pattern_search.group(9))
            list_of_relations.append(relation_dict)
    
    return list_of_relations

# %%
list_of_all_relations = list()

for file in os.listdir(beth_file_path+r'\rel'):
    file_path = os.path.join(beth_file_path+r'\rel', file)
    list_of_all_relations.extend(get_relations_from_file(file_path,file,'beth'))

for file in os.listdir(partners_file_path+r'\rel'):
    file_path = os.path.join(partners_file_path+r'\rel', file)
    list_of_all_relations.extend(get_relations_from_file(file_path,file,'partners'))

# %%
relation_df = pd.DataFrame(list_of_all_relations)

# %%
relation_df.head()
# Out:
#   source       file_name         from_text  from_line_number  \
# 0   beth  record-105.rel              cath                21
# 1   beth  record-105.rel  pefusion imaging                19
# 2   beth  record-105.rel             drugs                12
# 3   beth  record-105.rel       metal plate                26
# 4   beth  record-105.rel            creams               145
#
#    from_begin_word_num  from_end_word_num relation_type            to_text  \
# 0                    0                  0          TeRP      80% lm lesion
# 1                    6                  7          TeRP  perfusion defects
# 2                    8                  8          TrCP    known allergies
# 3                    7                  8          TrAP                gsw
# 4                   14                 14         TrNAP      any incisions
#
#    to_line_number  to_begin_word_num  to_end_word_num
# 0              21                  6                8
# 1              19                 12               13
# 2              12                  5                6
# 3              26                 11               11
# 4             145                 20               21

# %%
relation_df.groupby(['relation_type']).size()
# Out:
# relation_type
# PIP      755
# TeCP     166
# TeRP     993
# TrAP     885
# TrCP     184
# TrIP      51
# TrNAP     62
# TrWP      24
# dtype: int64

# %%
text = r"C:/Users/itsma/Documents/CS 6120 Project/Data/concept_assertion_relation_training_data/beth/txt/record-105.txt"

oFile = open(text, 'r')
line = oFile.read()

# %%
line

# %%
line.split("\n")[25].split()

# %%
for file in tqdm(os.listdir(beth_file_path+r'\txt')):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(beth_file_path+r'\txt', file)
    file_name = file.strip(".txt")
    oFile = open(file_path, 'r')
    line = oFile.read()
    all_lines = line.split("\n")
    
    file_concepts = concept_df[(concept_df['file_name']==file_name)&(concept_df['source']=='beth')]
    
    for index,row in file_concepts.iterrows():
        words = all_lines[int(row['line_number'])-1].split()[int(row['begin_word_num']):int(row['end_word_num'])+1]
        if(" ".join(words).lower()!=row['text'].lower()):
            print(row)

# %%
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased', return_dict=True)

inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
outputs = model(**inputs)

# %%
inputs

# %%
encodings = tokenizer.encode("Hello, my dog is cute",add_special_tokens = True)

# %%
encodings

# %%
input_ids = torch.tensor(encodings).long().unsqueeze(0)
        
outputs = model(input_ids,token_type_ids=None)

# %%
len(outputs[0][0][5].data.numpy())

# %%
from BERT_utility import BERT_utility

# %%
from imp import reload

# %%
import BERT_utility

# %%
reload(BERT_utility)
# Out:
# <module 'BERT_utility' from 'C:\\Users\\itsma\\Documents\\CS 6120 Project\\CS6120\\Code\\BERT_utility.py'>

# %%
utility = BERT_utility()
#word_list = utility.process_string_finetune(line,0)

# %%
def create_pos_dict(concept):
    positions = dict()
    
    for index,row in concept.iterrows():
        for i in range(row['begin_word_num'],row['end_word_num']+1):
            positions[str(row['line_number'])+":"+str(i)] = row['concept_type']
    
    return positions

# %%
utility = BERT_utility()

all_words_list = list()
for file in tqdm(os.listdir(beth_file_path+r'\txt')):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(beth_file_path+r'\txt', file)
    file_name = file.strip(".txt")
    oFile = open(file_path, 'r')
    line = oFile.read()
    all_lines = line.split("\n")
    file_concepts = concept_df[(concept_df['file_name']==file_name)&(concept_df['source']=='beth')]
    positions = create_pos_dict(file_concepts)
    
    word_list = utility.process_string_finetune(line,0)
    
    for entry in word_list:
        key = str(entry['sentence_index'])+ ":" +str(entry['word_index'])
        if(key in positions):
            entry.update({"concept":positions[key]})
        else:
            entry.update({"concept":"blank"})
    
    all_words_list.extend(word_list)
# Out:
#   0%|                                                                                           | 0/74 [00:00<?, ?it/s]
# {'word': 'Admission', 'keyword_vector': array([ 8.359914 , -2.136409 , -3.1871119, -2.7117975], dtype=float32), 'sentence_index': 1, 'word_index': 0}
# {'word': 'Date', 'keyword_vector': array([ 8.403783 , -2.1000547, -3.126127 , -2.758141 ], dtype=float32), 'sentence_index': 1, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.456588 , -2.1012568, -3.163484 , -2.7142665], dtype=float32), 'sentence_index': 1, 'word_index': 2}
# {'word': '2017-06-13', 'keyword_vector': array([ 8.409215 , -2.4124577, -3.0627542, -2.6660285], dtype=float32), 'sentence_index': 2, 'word_index': 0}
# {'word': 'Discharge', 'keyword_vector': array([ 8.428832 , -2.3091574, -2.9810236, -2.7452831], dtype=float32), 'sentence_index': 3, 'word_index': 0}
# {'word': 'Date', 'keyword_vector': array([ 8.411113 , -2.1695185, -3.0106492, -2.7994552], dtype=float32), 'sentence_index': 3, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.47194  , -2.146113 , -3.0365047, -2.7956421], dtype=float32), 'sentence_index': 3, 'word_index': 2}
# {'word': '2017-06-17', 'keyword_vector': array([ 8.411161 , -2.4591718, -3.0507169, -2.600467 ], dtype=float32), 'sentence_index': 4, 'word_index': 0}
# {'word': 'Date', 'keyword_vector': array([ 8.283782 , -1.8235086, -3.2579823, -2.7603867], dtype=float32), 'sentence_index': 5, 'word_index': 0}
# {'word': 'of', 'keyword_vector': array([ 8.268533 , -1.7730918, -3.221983 , -2.8380992], dtype=float32), 'sentence_index': 5, 'word_index': 1}
# {'word': 'Birth', 'keyword_vector': array([ 8.224948 , -1.7629527, -3.1939917, -2.8852391], dtype=float32), 'sentence_index': 5, 'word_index': 2}
# {'word': ':', 'keyword_vector': array([ 8.372965 , -1.797062 , -3.2097774, -2.8171396], dtype=float32), 'sentence_index': 5, 'word_index': 3}
# {'word': '1956-02-17', 'keyword_vector': array([ 8.438032 , -2.481205 , -3.0376968, -2.5647788], dtype=float32), 'sentence_index': 6, 'word_index': 0}
# {'word': 'Sex', 'keyword_vector': array([ 8.36928  , -2.0400949, -3.2596824, -2.5155494], dtype=float32), 'sentence_index': 7, 'word_index': 0}
# {'word': ':', 'keyword_vector': array([ 8.366658 , -1.8374842, -3.4435692, -2.5922208], dtype=float32), 'sentence_index': 7, 'word_index': 1}
# {'word': 'M', 'keyword_vector': array([ 8.136678 , -2.2563846, -3.5117579, -1.8724529], dtype=float32), 'sentence_index': 8, 'word_index': 0}
# {'word': 'Service', 'keyword_vector': array([ 8.20275 , -2.684607, -3.266429, -1.718192], dtype=float32), 'sentence_index': 9, 'word_index': 0}
# {'word': ':', 'keyword_vector': array([ 8.251624 , -2.5255628, -3.474074 , -1.7685087], dtype=float32), 'sentence_index': 9, 'word_index': 1}
# {'word': 'CARDIOTHORACIC', 'keyword_vector': array([ 7.1443977 , -2.9022198 , -3.2769098 ,  0.19231647], dtype=float32), 'sentence_index': 10, 'word_index': 0}
# {'word': 'Allergies', 'keyword_vector': array([ 8.26426  , -1.8863758, -3.6719825, -2.2556572], dtype=float32), 'sentence_index': 11, 'word_index': 0}
# {'word': ':', 'keyword_vector': array([ 8.303792 , -1.805144 , -3.7435205, -2.2134311], dtype=float32), 'sentence_index': 11, 'word_index': 1}
# {'word': 'Patient', 'keyword_vector': array([ 8.267041 , -1.7131732, -3.217874 , -2.8976152], dtype=float32), 'sentence_index': 12, 'word_index': 0}
# {'word': 'recorded', 'keyword_vector': array([ 8.203878 , -1.5264336, -3.228419 , -2.971805 ], dtype=float32), 'sentence_index': 12, 'word_index': 1}
# {'word': 'as', 'keyword_vector': array([ 8.290793 , -1.7428783, -3.0596485, -2.86848  ], dtype=float32), 'sentence_index': 12, 'word_index': 2}
# {'word': 'having', 'keyword_vector': array([ 8.278777 , -1.6755532, -3.1230931, -2.8949425], dtype=float32), 'sentence_index': 12, 'word_index': 3}
# {'word': 'No', 'keyword_vector': array([ 8.184498 , -1.2173443, -3.4556024, -2.8062453], dtype=float32), 'sentence_index': 12, 'word_index': 4}
# {'word': 'Known', 'keyword_vector': array([-0.7624463,  6.650274 , -3.0441546, -2.8658493], dtype=float32), 'sentence_index': 12, 'word_index': 5}
# {'word': 'Allergies', 'keyword_vector': array([-1.3556029,  6.805796 , -3.103131 , -2.634651 ], dtype=float32), 'sentence_index': 12, 'word_index': 6}
# {'word': 'to', 'keyword_vector': array([ 1.5409781,  1.6453022, -2.3645568, -1.0428623], dtype=float32), 'sentence_index': 12, 'word_index': 7}
# {'word': 'Drugs', 'keyword_vector': array([-0.9835613,  0.9589739, -1.0373243,  1.1492342], dtype=float32), 'sentence_index': 12, 'word_index': 8}
# {'word': 'Attending:Jordan', 'keyword_vector': array([ 8.3958235, -2.171745 , -2.9915848, -2.733741 ], dtype=float32), 'sentence_index': 13, 'word_index': 0}
# {'word': 'U', 'keyword_vector': array([ 8.367092 , -2.118542 , -3.0884395, -2.630394 ], dtype=float32), 'sentence_index': 13, 'word_index': 1}
# {'word': 'Kostohryz', 'keyword_vector': array([ 8.37279  , -2.1394966, -3.0084376, -2.6753635], dtype=float32), 'sentence_index': 13, 'word_index': 2}
# {'word': ',', 'keyword_vector': array([ 8.347847 , -2.2220347, -2.9726324, -2.7527854], dtype=float32), 'sentence_index': 13, 'word_index': 3}
# {'word': 'M.D.', 'keyword_vector': array([ 8.338133 , -2.2308807, -2.953012 , -2.742437 ], dtype=float32), 'sentence_index': 13, 'word_index': 4}
# {'word': 'Chief', 'keyword_vector': array([ 8.005956 , -1.4844488, -3.4987986, -2.8195279], dtype=float32), 'sentence_index': 14, 'word_index': 0}
# {'word': 'Complaint:', 'keyword_vector': array([ 8.099385 , -1.4451935, -3.480845 , -2.8856947], dtype=float32), 'sentence_index': 14, 'word_index': 1}
# {'word': 'recent', 'keyword_vector': array([-0.8001353,  7.008444 , -3.4685514, -2.6957386], dtype=float32), 'sentence_index': 14, 'word_index': 2}
# {'word': 'mild', 'keyword_vector': array([-1.9772558,  7.674505 , -3.221603 , -2.642963 ], dtype=float32), 'sentence_index': 14, 'word_index': 3}
# {'word': 'angina', 'keyword_vector': array([-2.4611135,  7.705886 , -3.0039186, -2.6019473], dtype=float32), 'sentence_index': 14, 'word_index': 4}
# {'word': 'with', 'keyword_vector': array([ 6.3231826 ,  0.17280445, -3.8495903 , -2.4560149 ], dtype=float32), 'sentence_index': 14, 'word_index': 5}
# {'word': 'exertion', 'keyword_vector': array([ 6.1221175, -1.4175051, -2.533522 , -1.5921803], dtype=float32), 'sentence_index': 14, 'word_index': 6}
# {'word': 'Major', 'keyword_vector': array([ 8.163701 , -2.291654 , -3.425226 , -1.7804216], dtype=float32), 'sentence_index': 15, 'word_index': 0}
# {'word': 'Surgical', 'keyword_vector': array([ 8.143022 , -2.2529407, -3.388626 , -1.8846526], dtype=float32), 'sentence_index': 15, 'word_index': 1}
# {'word': 'or', 'keyword_vector': array([ 8.1886015, -2.298249 , -3.3128934, -1.8037708], dtype=float32), 'sentence_index': 15, 'word_index': 2}
# {'word': 'Invasive', 'keyword_vector': array([ 8.17295  , -2.2104812, -3.362995 , -1.9313514], dtype=float32), 'sentence_index': 15, 'word_index': 3}
# {'word': 'Procedure', 'keyword_vector': array([ 8.180253 , -2.3374171, -3.3757029, -1.8654498], dtype=float32), 'sentence_index': 15, 'word_index': 4}
# {'word': ':', 'keyword_vector': array([ 8.275229 , -2.3798633, -3.3888364, -1.7704954], dtype=float32), 'sentence_index': 15, 'word_index': 5}
# {'word': 'emergency', 'keyword_vector': array([-1.3160566, -2.1913855, -2.506808 ,  6.475626 ], dtype=float32), 'sentence_index': 16, 'word_index': 0}
# {'word': 'CABG', 'keyword_vector': array([-1.6249697, -1.8975554, -2.7523508,  7.040351 ], dtype=float32), 'sentence_index': 16, 'word_index': 1}
# {'word': 'X', 'keyword_vector': array([ 7.4324636, -2.6630807, -3.0446873, -1.2241602], dtype=float32), 'sentence_index': 16, 'word_index': 2}
# {'word': '3', 'keyword_vector': array([ 7.0439973 , -3.2008991 , -2.9040887 , -0.44213602], dtype=float32), 'sentence_index': 16, 'word_index': 3}
# {'word': '(', 'keyword_vector': array([ 8.13988  , -2.842473 , -3.1839333, -1.7497294], dtype=float32), 'sentence_index': 16, 'word_index': 4}
# {'word': '2017-06-13', 'keyword_vector': array([ 8.035143 , -2.6359591, -3.0340066, -2.0103962], dtype=float32), 'sentence_index': 16, 'word_index': 5}
# {'word': ')(', 'keyword_vector': array([ 7.620502 , -3.1626978, -2.9896958, -0.579986 ], dtype=float32), 'sentence_index': 16, 'word_index': 6}
# {'word': 'LIMA', 'keyword_vector': array([-1.079915 , -2.4007604, -2.8753896,  7.109839 ], dtype=float32), 'sentence_index': 16, 'word_index': 7}
# {'word': 'to', 'keyword_vector': array([-0.35828188, -2.3422737 , -3.0507915 ,  6.730343  ], dtype=float32), 'sentence_index': 16, 'word_index': 8}
# {'word': 'LAD', 'keyword_vector': array([-0.8919015, -2.1749568, -3.057631 ,  7.1395254], dtype=float32), 'sentence_index': 16, 'word_index': 9}
# {'word': ',', 'keyword_vector': array([ 6.0531335, -3.4204576, -3.1541362,  0.9188891], dtype=float32), 'sentence_index': 16, 'word_index': 10}
# {'word': 'SVG', 'keyword_vector': array([-0.8263097, -2.392464 , -2.84058  ,  6.9101744], dtype=float32), 'sentence_index': 16, 'word_index': 11}
# {'word': 'to', 'keyword_vector': array([-0.23981531, -2.31472   , -3.108416  ,  6.7078476 ], dtype=float32), 'sentence_index': 16, 'word_index': 12}
# {'word': 'ramus', 'keyword_vector': array([-0.73744905, -2.2321985 , -3.0788214 ,  7.157113  ], dtype=float32), 'sentence_index': 16, 'word_index': 13}
# {'word': ',', 'keyword_vector': array([ 6.0008597, -3.4517124, -3.2633324,  0.9794648], dtype=float32), 'sentence_index': 16, 'word_index': 14}
# {'word': 'SVG', 'keyword_vector': array([-0.79847306, -2.3330631 , -2.90768   ,  6.9006596 ], dtype=float32), 'sentence_index': 16, 'word_index': 15}
# {'word': 'to', 'keyword_vector': array([-0.38494858, -2.2677813 , -3.1153128 ,  6.823037  ], dtype=float32), 'sentence_index': 16, 'word_index': 16}
# {'word': 'OM', 'keyword_vector': array([-0.7625366, -2.0765095, -3.1653361,  7.163417 ], dtype=float32), 'sentence_index': 16, 'word_index': 17}
# {'word': ')', 'keyword_vector': array([ 7.5605454, -3.2172813, -3.1944857, -0.5732532], dtype=float32), 'sentence_index': 16, 'word_index': 18}
# {'word': 'History', 'keyword_vector': array([ 7.928145 , -0.6020079, -3.8130434, -2.9153695], dtype=float32), 'sentence_index': 17, 'word_index': 0}
# {'word': 'of', 'keyword_vector': array([ 7.8655567 , -0.44041288, -3.8094187 , -2.9500325 ], dtype=float32), 'sentence_index': 17, 'word_index': 1}
# {'word': 'Present', 'keyword_vector': array([ 7.7126164 , -0.06426048, -3.8360715 , -3.212239  ], dtype=float32), 'sentence_index': 17, 'word_index': 2}
# {'word': 'Illness', 'keyword_vector': array([ 7.7430043 , -0.17027105, -3.8737497 , -3.2099774 ], dtype=float32), 'sentence_index': 17, 'word_index': 3}
# {'word': ':', 'keyword_vector': array([ 8.073024 , -0.6906877, -3.8143046, -2.9061587], dtype=float32), 'sentence_index': 17, 'word_index': 4}
# {'word': '61', 'keyword_vector': array([ 7.7836304, -1.8929217, -3.0170803, -2.560297 ], dtype=float32), 'sentence_index': 18, 'word_index': 0}
# {'word': 'yo', 'keyword_vector': array([ 8.092429 , -1.554818 , -3.1295953, -2.8079433], dtype=float32), 'sentence_index': 18, 'word_index': 1}
# {'word': 'African-American-Hispanic', 'keyword_vector': array([ 8.037169 , -1.5474677, -3.144216 , -2.71539  ], dtype=float32), 'sentence_index': 18, 'word_index': 2}
# {'word': 'male', 'keyword_vector': array([ 7.928791 , -1.6057688, -3.2802582, -2.6964695], dtype=float32), 'sentence_index': 18, 'word_index': 3}
# {'word': 'had', 'keyword_vector': array([ 8.052149 , -1.6660308, -3.3739476, -2.8682194], dtype=float32), 'sentence_index': 18, 'word_index': 4}
# {'word': 'abnormal', 'keyword_vector': array([-1.1609366,  7.153261 , -2.860919 , -3.3675692], dtype=float32), 'sentence_index': 18, 'word_index': 5}
# {'word': 'EKG', 'keyword_vector': array([-1.7575215,  7.3296123, -2.5559988, -3.1920314], dtype=float32), 'sentence_index': 18, 'word_index': 6}
# {'word': 'found', 'keyword_vector': array([ 7.9791684, -2.097917 , -2.882568 , -2.7803283], dtype=float32), 'sentence_index': 18, 'word_index': 7}
# {'word': 'as', 'keyword_vector': array([ 7.9412236, -2.5466645, -2.558807 , -2.4713209], dtype=float32), 'sentence_index': 18, 'word_index': 8}
# {'word': 'part', 'keyword_vector': array([ 7.212883 , -3.2619512, -1.5415047, -2.366581 ], dtype=float32), 'sentence_index': 18, 'word_index': 9}
# {'word': 'of', 'keyword_vector': array([ 7.274218 , -3.147582 , -1.6746116, -2.0171835], dtype=float32), 'sentence_index': 18, 'word_index': 10}
# {'word': 'pre-op', 'keyword_vector': array([-1.4974128, -3.0508683,  5.982107 , -2.2249365], dtype=float32), 'sentence_index': 18, 'word_index': 11}
# {'word': 'eval.', 'keyword_vector': array([-2.1905978, -2.9823024,  5.9779153, -1.6155453], dtype=float32), 'sentence_index': 18, 'word_index': 12}
# {'word': 'for', 'keyword_vector': array([ 6.861408 , -3.308284 , -2.053724 , -1.1694081], dtype=float32), 'sentence_index': 18, 'word_index': 13}
# {'word': 'ventral', 'keyword_vector': array([-2.6147597, -0.4964883, -2.702592 ,  6.592866 ], dtype=float32), 'sentence_index': 18, 'word_index': 14}
# {'word': 'hernia', 'keyword_vector': array([-2.7493386 , -0.16624632, -2.742383  ,  6.4423056 ], dtype=float32), 'sentence_index': 18, 'word_index': 15}
# {'word': 'repair', 'keyword_vector': array([-2.3576558 , -0.62528133, -2.7415776 ,  6.5070124 ], dtype=float32), 'sentence_index': 18, 'word_index': 16}
# {'word': '.', 'keyword_vector': array([ 7.8571663, -1.3757317, -3.3128927, -2.4863496], dtype=float32), 'sentence_index': 18, 'word_index': 17}
# {'word': 'Had', 'keyword_vector': array([ 7.609017  , -0.77038616, -3.2300866 , -3.1079924 ], dtype=float32), 'sentence_index': 19, 'word_index': 0}
# {'word': 'subsequent', 'keyword_vector': array([ 5.8031974 ,  0.08027996, -2.7097697 , -2.5642    ], dtype=float32), 'sentence_index': 19, 'word_index': 1}
# {'word': 'abnormal', 'keyword_vector': array([-1.725964 ,  7.476301 , -2.9123476, -3.2931352], dtype=float32), 'sentence_index': 19, 'word_index': 2}
# {'word': 'stress', 'keyword_vector': array([-2.3699021,  7.547555 , -2.6179085, -2.99409  ], dtype=float32), 'sentence_index': 19, 'word_index': 3}
# {'word': 'test', 'keyword_vector': array([-2.2164183,  7.5848403, -2.6596842, -3.073862 ], dtype=float32), 'sentence_index': 19, 'word_index': 4}
# {'word': 'and', 'keyword_vector': array([ 7.3633747, -1.1384139, -3.136068 , -2.8062632], dtype=float32), 'sentence_index': 19, 'word_index': 5}
# {'word': 'pefusion', 'keyword_vector': array([-2.3250337, -2.887525 ,  6.5666056, -2.3571873], dtype=float32), 'sentence_index': 19, 'word_index': 6}
# {'word': 'imaging', 'keyword_vector': array([-2.4915292, -2.78075  ,  6.5509915, -2.380742 ], dtype=float32), 'sentence_index': 19, 'word_index': 7}
# {'word': 'showed', 'keyword_vector': array([ 7.5730567, -1.4118093, -2.54351  , -3.3513548], dtype=float32), 'sentence_index': 19, 'word_index': 8}
# {'word': 'EF', 'keyword_vector': array([-1.7881387, -2.4536285,  6.409587 , -3.1884437], dtype=float32), 'sentence_index': 19, 'word_index': 9}
# {'word': '38%', 'keyword_vector': array([ 7.033994  , -0.85037124, -2.721106  , -3.0944376 ], dtype=float32), 'sentence_index': 19, 'word_index': 10}
# {'word': 'with', 'keyword_vector': array([ 7.3471665, -1.0102555, -2.9339871, -3.3449705], dtype=float32), 'sentence_index': 19, 'word_index': 11}
# {'word': 'perfusion', 'keyword_vector': array([-2.0002708,  7.4878035, -2.4501996, -2.8905222], dtype=float32), 'sentence_index': 19, 'word_index': 12}
# {'word': 'defects', 'keyword_vector': array([-2.2611148,  7.5747957, -2.5236745, -2.9284642], dtype=float32), 'sentence_index': 19, 'word_index': 13}
# {'word': '.', 'keyword_vector': array([ 7.5009346, -1.1007255, -2.9068437, -3.0720797], dtype=float32), 'sentence_index': 19, 'word_index': 14}
# {'word': 'Echo', 'keyword_vector': array([-1.3790611, -2.8672318,  6.434994 , -3.0935838], dtype=float32), 'sentence_index': 20, 'word_index': 0}
# {'word': 'prior', 'keyword_vector': array([ 6.7364326, -2.9753754, -1.1281004, -2.4517753], dtype=float32), 'sentence_index': 20, 'word_index': 1}
# {'word': 'to', 'keyword_vector': array([ 7.5155063, -2.898029 , -1.5791708, -2.3247933], dtype=float32), 'sentence_index': 20, 'word_index': 2}
# {'word': 'scheduled', 'keyword_vector': array([-1.6973873, -2.7823365,  5.318628 , -1.3684236], dtype=float32), 'sentence_index': 20, 'word_index': 3}
# {'word': 'cath', 'keyword_vector': array([-2.9543176, -2.4182525,  5.828573 , -1.262391 ], dtype=float32), 'sentence_index': 20, 'word_index': 4}
# {'word': 'showed', 'keyword_vector': array([ 7.9349084, -2.3222084, -2.224117 , -3.0838034], dtype=float32), 'sentence_index': 20, 'word_index': 5}
# {'word': 'mild', 'keyword_vector': array([-1.4909426,  7.4329095, -3.1280603, -3.0540018], dtype=float32), 'sentence_index': 20, 'word_index': 6}
# {'word': 'LVH', 'keyword_vector': array([-1.9958826,  7.563856 , -2.9214694, -3.0216532], dtype=float32), 'sentence_index': 20, 'word_index': 7}
# {'word': ',', 'keyword_vector': array([ 7.488178 , -1.9515488, -2.409735 , -2.9089053], dtype=float32), 'sentence_index': 20, 'word_index': 8}
# {'word': 'inferior', 'keyword_vector': array([-1.7437487,  7.7670126, -2.9646091, -3.053029 ], dtype=float32), 'sentence_index': 20, 'word_index': 9}
# {'word': 'HK', 'keyword_vector': array([-2.1504574,  7.676548 , -2.8883638, -3.0765822], dtype=float32), 'sentence_index': 20, 'word_index': 10}
# {'word': ',', 'keyword_vector': array([ 7.671675 , -2.225154 , -2.2258499, -2.89246  ], dtype=float32), 'sentence_index': 20, 'word_index': 11}
# {'word': 'EF', 'keyword_vector': array([-1.4817562, -2.6854637,  6.3494573, -3.191591 ], dtype=float32), 'sentence_index': 20, 'word_index': 12}
# {'word': '40%', 'keyword_vector': array([ 6.9965014, -1.6081591, -2.104971 , -2.9474738], dtype=float32), 'sentence_index': 20, 'word_index': 13}
# {'word': ',', 'keyword_vector': array([ 7.7534757, -2.296867 , -2.2595003, -2.9775996], dtype=float32), 'sentence_index': 20, 'word_index': 14}
# {'word': 'mild', 'keyword_vector': array([-1.5221953,  7.525832 , -3.1836166, -2.9956048], dtype=float32), 'sentence_index': 20, 'word_index': 15}
# {'word': 'MR', 'keyword_vector': array([-2.073798 ,  7.6304445, -2.981082 , -2.956505 ], dtype=float32), 'sentence_index': 20, 'word_index': 16}
# {'word': ',', 'keyword_vector': array([ 7.6860156, -2.0769525, -2.462442 , -2.9949348], dtype=float32), 'sentence_index': 20, 'word_index': 17}
# {'word': 'mild', 'keyword_vector': array([-1.3712578,  7.4261613, -3.164063 , -3.029808 ], dtype=float32), 'sentence_index': 20, 'word_index': 18}
# {'word': 'LAE', 'keyword_vector': array([-2.08429  ,  7.6035357, -2.9174132, -2.9596686], dtype=float32), 'sentence_index': 20, 'word_index': 19}
# {'word': '.', 'keyword_vector': array([ 7.3155627, -2.4710312, -1.5539174, -2.996342 ], dtype=float32), 'sentence_index': 20, 'word_index': 20}
# {'word': 'Cath', 'keyword_vector': array([-2.8104231, -3.014535 ,  6.3640013, -1.5741804], dtype=float32), 'sentence_index': 21, 'word_index': 0}
# {'word': 'at', 'keyword_vector': array([ 7.965936 , -2.9286857, -1.8906697, -2.971051 ], dtype=float32), 'sentence_index': 21, 'word_index': 1}
# {'word': 'Kindred/North', 'keyword_vector': array([ 8.305609 , -2.2508898, -2.7253118, -2.979346 ], dtype=float32), 'sentence_index': 21, 'word_index': 2}
# {'word': 'Shore', 'keyword_vector': array([ 8.253272 , -2.1548176, -2.788673 , -3.0399077], dtype=float32), 'sentence_index': 21, 'word_index': 3}
# {'word': 'today', 'keyword_vector': array([ 7.942044 , -2.7152483, -2.052683 , -3.1491787], dtype=float32), 'sentence_index': 21, 'word_index': 4}
# {'word': 'showed', 'keyword_vector': array([ 8.215923 , -2.1013525, -2.5576944, -3.1930735], dtype=float32), 'sentence_index': 21, 'word_index': 5}
# {'word': '80%', 'keyword_vector': array([-1.8541031,  7.5870786, -3.150458 , -2.9481604], dtype=float32), 'sentence_index': 21, 'word_index': 6}
# {'word': 'LM', 'keyword_vector': array([-2.2961688,  7.6971636, -3.0069456, -2.8376546], dtype=float32), 'sentence_index': 21, 'word_index': 7}
# {'word': 'lesion', 'keyword_vector': array([-2.3677106,  7.6863303, -2.9605956, -2.8347297], dtype=float32), 'sentence_index': 21, 'word_index': 8}
# {'word': 'with', 'keyword_vector': array([ 7.991424 , -1.9293422, -2.4468489, -3.255411 ], dtype=float32), 'sentence_index': 21, 'word_index': 9}
# {'word': 'normal', 'keyword_vector': array([ 7.308678 , -1.9913422, -2.1995168, -2.7298615], dtype=float32), 'sentence_index': 21, 'word_index': 10}
# {'word': 'LAD', 'keyword_vector': array([ 7.1435294, -1.8902562, -1.5698228, -3.280641 ], dtype=float32), 'sentence_index': 21, 'word_index': 11}
# {'word': ',', 'keyword_vector': array([ 7.4456873, -1.9144654, -2.2947102, -3.0172555], dtype=float32), 'sentence_index': 21, 'word_index': 12}
# {'word': 'CX', 'keyword_vector': array([ 7.0948677, -1.8046954, -1.7162225, -3.124514 ], dtype=float32), 'sentence_index': 21, 'word_index': 13}
# {'word': ',', 'keyword_vector': array([ 7.4097757, -1.7300466, -2.3006458, -3.188711 ], dtype=float32), 'sentence_index': 21, 'word_index': 14}
# {'word': 'RCA', 'keyword_vector': array([ 7.225107 , -1.8194104, -1.8409323, -3.195483 ], dtype=float32), 'sentence_index': 21, 'word_index': 15}
# {'word': '.', 'keyword_vector': array([ 7.90184  , -2.1806788, -2.1605716, -3.150728 ], dtype=float32), 'sentence_index': 21, 'word_index': 16}
# {'word': 'Severe', 'keyword_vector': array([-2.3926103,  7.6053786, -2.9171576, -2.4731414], dtype=float32), 'sentence_index': 22, 'word_index': 0}
# {'word': 'systolic', 'keyword_vector': array([-2.7851145,  7.686666 , -2.7660954, -2.3869555], dtype=float32), 'sentence_index': 22, 'word_index': 1}
# {'word': 'HTN', 'keyword_vector': array([-2.9791777,  7.640907 , -2.6077292, -2.4398334], dtype=float32), 'sentence_index': 22, 'word_index': 2}
# {'word': 'also', 'keyword_vector': array([ 8.08248  , -1.9309202, -2.9112027, -2.8360088], dtype=float32), 'sentence_index': 22, 'word_index': 3}
# {'word': 'noted', 'keyword_vector': array([ 7.982257 , -2.0159087, -2.7191243, -3.0634155], dtype=float32), 'sentence_index': 22, 'word_index': 4}
# {'word': '.', 'keyword_vector': array([ 8.1121435, -1.860897 , -2.9097438, -2.9144895], dtype=float32), 'sentence_index': 22, 'word_index': 5}
# {'word': 'Transferred', 'keyword_vector': array([ 8.323267 , -2.7304578, -3.1151662, -2.0964406], dtype=float32), 'sentence_index': 23, 'word_index': 0}
# {'word': 'in', 'keyword_vector': array([ 8.339604 , -2.5127776, -3.2260175, -2.0960004], dtype=float32), 'sentence_index': 23, 'word_index': 1}
# {'word': 'urgently', 'keyword_vector': array([ 8.2997   , -2.5197768, -3.2986984, -1.9505069], dtype=float32), 'sentence_index': 23, 'word_index': 2}
# {'word': 'for', 'keyword_vector': array([ 7.917607 , -3.1072009, -2.9084542, -1.3466055], dtype=float32), 'sentence_index': 23, 'word_index': 3}
# {'word': 'cabg', 'keyword_vector': array([-2.3172913, -1.6334113, -2.268836 ,  6.963604 ], dtype=float32), 'sentence_index': 23, 'word_index': 4}
# {'word': 'with', 'keyword_vector': array([ 7.884154 , -3.135663 , -2.8650782, -1.3676798], dtype=float32), 'sentence_index': 23, 'word_index': 5}
# {'word': 'Dr.', 'keyword_vector': array([ 8.153576 , -2.9570994, -2.759105 , -1.9521464], dtype=float32), 'sentence_index': 23, 'word_index': 6}
# {'word': 'Howard', 'keyword_vector': array([ 7.6877894, -2.4310236, -2.9769773, -1.7074485], dtype=float32), 'sentence_index': 23, 'word_index': 7}
# {'word': '.', 'keyword_vector': array([ 8.240963 , -2.8479166, -3.0340323, -1.7844605], dtype=float32), 'sentence_index': 23, 'word_index': 8}
# {'word': 'Past', 'keyword_vector': array([ 8.312477 , -1.796934 , -3.3449128, -2.5588744], dtype=float32), 'sentence_index': 24, 'word_index': 0}
# {'word': 'Medical', 'keyword_vector': array([ 8.285329 , -1.7471408, -3.3615596, -2.6206264], dtype=float32), 'sentence_index': 24, 'word_index': 1}
# {'word': 'History', 'keyword_vector': array([ 8.29093  , -1.8059226, -3.4373996, -2.5116425], dtype=float32), 'sentence_index': 24, 'word_index': 2}
# {'word': ':', 'keyword_vector': array([ 8.361559 , -1.8703154, -3.4047132, -2.5040057], dtype=float32), 'sentence_index': 24, 'word_index': 3}
# {'word': 'ventral', 'keyword_vector': array([-2.7318926,  7.5665164, -2.8110585, -2.4483564], dtype=float32), 'sentence_index': 25, 'word_index': 0}
# {'word': 'hernia', 'keyword_vector': array([-2.9173865,  7.5811167, -2.78346  , -2.3404636], dtype=float32), 'sentence_index': 25, 'word_index': 1}
# {'word': 'HTN', 'keyword_vector': array([-1.9864341,  7.3965125, -3.169953 , -2.5480978], dtype=float32), 'sentence_index': 26, 'word_index': 0}
# {'word': 'elev.', 'keyword_vector': array([-0.7716255,  6.7821064, -3.4023454, -2.71648  ], dtype=float32), 'sentence_index': 26, 'word_index': 1}
# {'word': 'chol.', 'keyword_vector': array([ 0.1262819,  5.3882785, -3.0898762, -2.553223 ], dtype=float32), 'sentence_index': 26, 'word_index': 2}
# {'word': 'right', 'keyword_vector': array([-1.6874888,  7.6057863, -3.286872 , -2.6950893], dtype=float32), 'sentence_index': 26, 'word_index': 3}
# {'word': 'facial', 'keyword_vector': array([-2.1513453,  7.7232447, -3.1211872, -2.534531 ], dtype=float32), 'sentence_index': 26, 'word_index': 4}
# {'word': 'droop', 'keyword_vector': array([-2.4069195,  7.708062 , -2.9421186, -2.507739 ], dtype=float32), 'sentence_index': 26, 'word_index': 5}
# {'word': 'with', 'keyword_vector': array([ 5.668591  , -0.50084966, -3.5836725 , -1.4568241 ], dtype=float32), 'sentence_index': 26, 'word_index': 6}
# {'word': 'metal', 'keyword_vector': array([-0.95184666, -0.78641456, -2.5245137 ,  5.073817  ], dtype=float32), 'sentence_index': 26, 'word_index': 7}
# {'word': 'plate', 'keyword_vector': array([-1.3119943 , -0.89598495, -2.6724727 ,  5.411419  ], dtype=float32), 'sentence_index': 26, 'word_index': 8}
# {'word': 'secondary', 'keyword_vector': array([ 5.1467013 ,  0.20717452, -3.1456733 , -2.2894335 ], dtype=float32), 'sentence_index': 26, 'word_index': 9}
# {'word': 'to', 'keyword_vector': array([ 6.0063844e+00,  2.7149182e-03, -3.1940744e+00, -2.2419293e+00],
#       dtype=float32), 'sentence_index': 26, 'word_index': 10}
# {'word': 'GSW', 'keyword_vector': array([-1.837065 ,  6.486488 , -2.8699327, -2.3125196], dtype=float32), 'sentence_index': 26, 'word_index': 11}
# {'word': 'to', 'keyword_vector': array([-1.2532977,  6.017885 , -2.930314 , -2.1228292], dtype=float32), 'sentence_index': 26, 'word_index': 12}
# {'word': 'face', 'keyword_vector': array([-1.398043 ,  6.4023895, -3.155378 , -1.8123553], dtype=float32), 'sentence_index': 26, 'word_index': 13}
# {'word': 'right', 'keyword_vector': array([-1.956277 ,  0.7769488, -2.5484521,  4.1896734], dtype=float32), 'sentence_index': 26, 'word_index': 14}
# {'word': 'nephrectomy', 'keyword_vector': array([-2.843885  ,  0.69731224, -2.5532038 ,  5.362092  ], dtype=float32), 'sentence_index': 26, 'word_index': 15}
# {'word': 'Social', 'keyword_vector': array([ 8.289912 , -1.9693366, -3.2690907, -2.6358962], dtype=float32), 'sentence_index': 27, 'word_index': 0}
# {'word': 'History', 'keyword_vector': array([ 8.310607 , -1.8036642, -3.3916898, -2.6518123], dtype=float32), 'sentence_index': 27, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.377252 , -1.80941  , -3.376733 , -2.6729486], dtype=float32), 'sentence_index': 27, 'word_index': 2}
# {'word': 'current', 'keyword_vector': array([ 7.9558673, -2.1960433, -2.6893024, -2.7186277], dtype=float32), 'sentence_index': 28, 'word_index': 0}
# {'word': 'smoker', 'keyword_vector': array([ 8.038834 , -2.316743 , -2.7479508, -2.6137528], dtype=float32), 'sentence_index': 28, 'word_index': 1}
# {'word': 'Family', 'keyword_vector': array([ 8.250177 , -1.835405 , -3.0946524, -3.0306768], dtype=float32), 'sentence_index': 29, 'word_index': 0}
# {'word': 'History', 'keyword_vector': array([ 8.278268 , -1.7179967, -3.2439451, -2.954717 ], dtype=float32), 'sentence_index': 29, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.363259 , -1.7219439, -3.2934206, -2.8950965], dtype=float32), 'sentence_index': 29, 'word_index': 2}
# {'word': 'not', 'keyword_vector': array([ 8.243751 , -2.2321444, -3.4973254, -2.0285628], dtype=float32), 'sentence_index': 30, 'word_index': 0}
# {'word': 'given', 'keyword_vector': array([ 8.213673 , -1.9005257, -3.5927272, -2.3933613], dtype=float32), 'sentence_index': 30, 'word_index': 1}
# {'word': 'Physical', 'keyword_vector': array([ 8.212836 , -2.5301871, -2.7319932, -2.4927058], dtype=float32), 'sentence_index': 31, 'word_index': 0}
# {'word': 'Exam:', 'keyword_vector': array([ 8.253967 , -2.337791 , -2.8895407, -2.5729377], dtype=float32), 'sentence_index': 31, 'word_index': 1}
# {'word': 'Not', 'keyword_vector': array([ 8.309158 , -2.3556976, -2.818735 , -2.6665814], dtype=float32), 'sentence_index': 32, 'word_index': 0}
# {'word': 'done', 'keyword_vector': array([ 8.198747 , -2.2199764, -2.6618795, -2.8641617], dtype=float32), 'sentence_index': 32, 'word_index': 1}
# {'word': ',', 'keyword_vector': array([ 8.327598 , -2.1975136, -2.786856 , -2.7113793], dtype=float32), 'sentence_index': 32, 'word_index': 2}
# {'word': 'taken', 'keyword_vector': array([ 8.330579 , -2.1998394, -2.836852 , -2.8593795], dtype=float32), 'sentence_index': 32, 'word_index': 3}
# {'word': 'to', 'keyword_vector': array([ 8.398423 , -2.101052 , -2.927022 , -2.7474706], dtype=float32), 'sentence_index': 32, 'word_index': 4}
# {'word': 'OR', 'keyword_vector': array([ 8.354694 , -2.2818975, -2.7115932, -2.7112925], dtype=float32), 'sentence_index': 32, 'word_index': 5}
# {'word': 'direct', 'keyword_vector': array([ 8.241691 , -2.0843728, -3.043538 , -2.5679584], dtype=float32), 'sentence_index': 32, 'word_index': 6}
# {'word': 'from', 'keyword_vector': array([ 8.306643 , -2.2260456, -2.9863715, -2.557824 ], dtype=float32), 'sentence_index': 32, 'word_index': 7}
# {'word': 'ambulance', 'keyword_vector': array([ 8.234612, -2.516835, -3.043829, -2.180304], dtype=float32), 'sentence_index': 32, 'word_index': 8}
# {'word': 'transfer', 'keyword_vector': array([ 8.203004 , -2.415977 , -3.0330744, -2.3524137], dtype=float32), 'sentence_index': 32, 'word_index': 9}
# {'word': '.', 'keyword_vector': array([ 8.235654 , -2.172858 , -2.7681289, -2.6691825], dtype=float32), 'sentence_index': 32, 'word_index': 10}
# {'word': 'Pertinent', 'keyword_vector': array([ 8.341512 , -2.4100797, -2.9336681, -2.6191924], dtype=float32), 'sentence_index': 33, 'word_index': 0}
# {'word': 'Results:', 'keyword_vector': array([ 8.344427 , -2.4368448, -2.8892207, -2.6715288], dtype=float32), 'sentence_index': 33, 'word_index': 1}
# {'word': '2017-06-14', 'keyword_vector': array([ 8.335779 , -2.5681286, -2.4900506, -3.0146978], dtype=float32), 'sentence_index': 34, 'word_index': 0}
# {'word': '02:06AM', 'keyword_vector': array([ 7.974451 , -2.6980233, -1.9049337, -3.2699547], dtype=float32), 'sentence_index': 34, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([ 0.34996626, -3.3868294 ,  4.8692865 , -3.0998344 ], dtype=float32), 'sentence_index': 34, 'word_index': 2}
# {'word': 'WBC', 'keyword_vector': array([-2.5445428, -2.8003116,  6.689982 , -2.7424421], dtype=float32), 'sentence_index': 35, 'word_index': 0}
# {'word': '-', 'keyword_vector': array([ 7.4565177, -2.7579074, -1.5782049, -3.2084363], dtype=float32), 'sentence_index': 35, 'word_index': 1}
# {'word': '9.4', 'keyword_vector': array([ 7.774704 , -2.751998 , -1.7854246, -3.241876 ], dtype=float32), 'sentence_index': 35, 'word_index': 2}
# {'word': 'RBC', 'keyword_vector': array([-2.359506 , -2.8549614,  6.577468 , -2.5840478], dtype=float32), 'sentence_index': 35, 'word_index': 3}
# {'word': '-', 'keyword_vector': array([ 7.433582 , -2.720284 , -1.7133871, -2.979398 ], dtype=float32), 'sentence_index': 35, 'word_index': 4}
# {'word': '3.61*', 'keyword_vector': array([ 7.7727704, -2.6047544, -1.9839913, -3.0419412], dtype=float32), 'sentence_index': 35, 'word_index': 5}
# {'word': 'Hgb', 'keyword_vector': array([-2.7626417, -2.6549   ,  6.5730367, -2.60868  ], dtype=float32), 'sentence_index': 35, 'word_index': 6}
# {'word': '-', 'keyword_vector': array([ 7.411635 , -2.687418 , -1.7837586, -2.9471176], dtype=float32), 'sentence_index': 35, 'word_index': 7}
# {'word': '10.4*', 'keyword_vector': array([ 7.733907 , -2.5951233, -1.8362064, -3.2509136], dtype=float32), 'sentence_index': 35, 'word_index': 8}
# {'word': 'Hct', 'keyword_vector': array([-2.7759447, -2.6431863,  6.750458 , -2.6210089], dtype=float32), 'sentence_index': 35, 'word_index': 9}
# {'word': '-', 'keyword_vector': array([ 7.383578 , -2.7052155, -1.76559  , -2.9852078], dtype=float32), 'sentence_index': 35, 'word_index': 10}
# {'word': '29.9*', 'keyword_vector': array([ 7.763972 , -2.6083982, -1.7959137, -3.3077106], dtype=float32), 'sentence_index': 35, 'word_index': 11}
# {'word': 'MCV', 'keyword_vector': array([-2.5160503, -2.7023273,  6.631454 , -2.628836 ], dtype=float32), 'sentence_index': 35, 'word_index': 12}
# {'word': '-', 'keyword_vector': array([ 7.5751004, -2.7392824, -1.8546474, -3.037269 ], dtype=float32), 'sentence_index': 35, 'word_index': 13}
# {'word': '83', 'keyword_vector': array([ 7.5353236, -2.3589804, -1.8200164, -3.288559 ], dtype=float32), 'sentence_index': 35, 'word_index': 14}
# {'word': 'MCH', 'keyword_vector': array([-2.578673 , -2.618741 ,  6.5959716, -2.570353 ], dtype=float32), 'sentence_index': 35, 'word_index': 15}
# {'word': '-', 'keyword_vector': array([ 7.4660773, -2.719524 , -1.6905625, -3.0946362], dtype=float32), 'sentence_index': 35, 'word_index': 16}
# {'word': '28.8', 'keyword_vector': array([ 7.796023 , -2.4834921, -1.9767708, -3.2257118], dtype=float32), 'sentence_index': 35, 'word_index': 17}
# {'word': 'MCHC', 'keyword_vector': array([-2.7129474, -2.6109753,  6.666984 , -2.5349863], dtype=float32), 'sentence_index': 35, 'word_index': 18}
# {'word': '-', 'keyword_vector': array([ 7.3973804, -2.7223887, -1.5876175, -3.1319952], dtype=float32), 'sentence_index': 35, 'word_index': 19}
# {'word': '34.8', 'keyword_vector': array([ 7.734239 , -2.4532807, -2.0286446, -3.1585083], dtype=float32), 'sentence_index': 35, 'word_index': 20}
# {'word': 'RDW', 'keyword_vector': array([-2.7701483, -2.6824355,  6.6994987, -2.4919987], dtype=float32), 'sentence_index': 35, 'word_index': 21}
# {'word': '-', 'keyword_vector': array([ 7.403988 , -2.6460254, -1.7906371, -3.1056113], dtype=float32), 'sentence_index': 35, 'word_index': 22}
# {'word': '14.3', 'keyword_vector': array([ 7.6824913, -2.4583302, -2.1315668, -3.091071 ], dtype=float32), 'sentence_index': 35, 'word_index': 23}
# {'word': 'Plt', 'keyword_vector': array([-2.579874 , -2.839347 ,  6.810126 , -2.6335797], dtype=float32), 'sentence_index': 35, 'word_index': 24}
# {'word': 'Ct', 'keyword_vector': array([-2.310976 , -2.9214642,  6.4515452, -2.6942298], dtype=float32), 'sentence_index': 35, 'word_index': 25}
# {'word': '-', 'keyword_vector': array([ 7.293348 , -2.8286924, -1.5728786, -3.143628 ], dtype=float32), 'sentence_index': 35, 'word_index': 26}
# {'word': '154', 'keyword_vector': array([ 7.290777 , -2.660659 , -2.0033727, -3.1092803], dtype=float32), 'sentence_index': 35, 'word_index': 27}
# {'word': '2017-06-17', 'keyword_vector': array([ 8.335409 , -2.6087756, -2.4639657, -2.9950287], dtype=float32), 'sentence_index': 36, 'word_index': 0}
# {'word': '05:14AM', 'keyword_vector': array([ 7.9968505, -2.7608058, -1.8738234, -3.2378116], dtype=float32), 'sentence_index': 36, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([ 0.48115852, -3.3744829 ,  4.764496  , -3.1323645 ], dtype=float32), 'sentence_index': 36, 'word_index': 2}
# {'word': 'Hct', 'keyword_vector': array([-2.9887645, -2.5544372,  6.6029067, -2.5813124], dtype=float32), 'sentence_index': 37, 'word_index': 0}
# {'word': '-', 'keyword_vector': array([ 7.463893 , -2.613955 , -1.067462 , -3.3487241], dtype=float32), 'sentence_index': 37, 'word_index': 1}
# {'word': '25.2*', 'keyword_vector': array([ 8.039842 , -2.5145059, -2.0310347, -3.2458997], dtype=float32), 'sentence_index': 37, 'word_index': 2}
# {'word': '2017-06-14', 'keyword_vector': array([ 8.335779 , -2.5681286, -2.4900506, -3.0146978], dtype=float32), 'sentence_index': 38, 'word_index': 0}
# {'word': '02:06AM', 'keyword_vector': array([ 7.974451 , -2.6980233, -1.9049337, -3.2699547], dtype=float32), 'sentence_index': 38, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([ 0.34996626, -3.3868294 ,  4.8692865 , -3.0998344 ], dtype=float32), 'sentence_index': 38, 'word_index': 2}
# {'word': 'Plt', 'keyword_vector': array([-2.799807 , -2.6553757,  6.8740983, -2.5910254], dtype=float32), 'sentence_index': 39, 'word_index': 0}
# {'word': 'Ct', 'keyword_vector': array([-2.3965175, -2.800799 ,  6.512409 , -2.74378  ], dtype=float32), 'sentence_index': 39, 'word_index': 1}
# {'word': '-', 'keyword_vector': array([ 6.070388  , -3.0800931 ,  0.22381042, -3.3046591 ], dtype=float32), 'sentence_index': 39, 'word_index': 2}
# {'word': '154', 'keyword_vector': array([ 7.0675406, -2.5801084, -1.861835 , -2.7589214], dtype=float32), 'sentence_index': 39, 'word_index': 3}
# {'word': '2017-06-13', 'keyword_vector': array([ 8.289713 , -2.5764623, -2.4667883, -3.0546768], dtype=float32), 'sentence_index': 40, 'word_index': 0}
# {'word': '08:05PM', 'keyword_vector': array([ 7.411525 , -2.908927 , -1.2389514, -3.3284943], dtype=float32), 'sentence_index': 40, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([-0.08344015, -3.3761437 ,  5.1769695 , -3.0683782 ], dtype=float32), 'sentence_index': 40, 'word_index': 2}
# {'word': 'PT', 'keyword_vector': array([-1.8928195, -2.8525004,  6.3162403, -3.109327 ], dtype=float32), 'sentence_index': 41, 'word_index': 0}
# {'word': '-', 'keyword_vector': array([ 6.9930944, -2.9030538, -0.8309888, -3.2370608], dtype=float32), 'sentence_index': 41, 'word_index': 1}
# {'word': '13.6*', 'keyword_vector': array([ 7.4985437, -2.782967 , -1.4418021, -3.3354502], dtype=float32), 'sentence_index': 41, 'word_index': 2}
# {'word': 'PTT', 'keyword_vector': array([-2.4490376, -2.6299124,  6.4452543, -2.7967567], dtype=float32), 'sentence_index': 41, 'word_index': 3}
# {'word': '-', 'keyword_vector': array([ 6.571509 , -2.8651938, -0.6236875, -2.9707103], dtype=float32), 'sentence_index': 41, 'word_index': 4}
# {'word': '33.3', 'keyword_vector': array([ 7.5599904, -2.6923244, -1.4775909, -3.1842601], dtype=float32), 'sentence_index': 41, 'word_index': 5}
# {'word': 'INR', 'keyword_vector': array([-1.1068323, -2.915101 ,  5.371997 , -2.8812833], dtype=float32), 'sentence_index': 41, 'word_index': 6}
# {'word': '(', 'keyword_vector': array([ 0.73577726, -3.1369348 ,  4.033659  , -3.1149461 ], dtype=float32), 'sentence_index': 41, 'word_index': 7}
# {'word': 'PT', 'keyword_vector': array([-0.756892 , -2.9267144,  5.1222835, -3.0305521], dtype=float32), 'sentence_index': 41, 'word_index': 8}
# {'word': ')', 'keyword_vector': array([ 0.8396357, -3.0088131,  3.672033 , -2.803139 ], dtype=float32), 'sentence_index': 41, 'word_index': 9}
# {'word': '-', 'keyword_vector': array([ 2.1847484, -2.916663 ,  2.5859027, -2.8403904], dtype=float32), 'sentence_index': 41, 'word_index': 10}
# {'word': '1.2*', 'keyword_vector': array([ 7.395408 , -2.841192 , -1.270068 , -3.2488704], dtype=float32), 'sentence_index': 41, 'word_index': 11}
# {'word': '2017-06-17', 'keyword_vector': array([ 8.335409 , -2.6087756, -2.4639657, -2.9950287], dtype=float32), 'sentence_index': 42, 'word_index': 0}
# {'word': '05:14AM', 'keyword_vector': array([ 7.9968505, -2.7608058, -1.8738234, -3.2378116], dtype=float32), 'sentence_index': 42, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([ 0.48115852, -3.3744829 ,  4.764496  , -3.1323645 ], dtype=float32), 'sentence_index': 42, 'word_index': 2}
# {'word': 'UreaN', 'keyword_vector': array([-2.7170033, -2.954231 ,  6.7109423, -2.4858856], dtype=float32), 'sentence_index': 43, 'word_index': 0}
# {'word': '-', 'keyword_vector': array([ 7.265313 , -2.7416706, -1.4115968, -3.0306706], dtype=float32), 'sentence_index': 43, 'word_index': 1}
# {'word': '25*', 'keyword_vector': array([ 7.7367625, -2.649232 , -1.7981493, -3.30545  ], dtype=float32), 'sentence_index': 43, 'word_index': 2}
# {'word': 'Creat', 'keyword_vector': array([-2.8586605, -2.7597237,  6.7679496, -2.2732341], dtype=float32), 'sentence_index': 43, 'word_index': 3}
# {'word': '-', 'keyword_vector': array([ 7.1671257, -2.797697 , -1.3634224, -2.94771  ], dtype=float32), 'sentence_index': 43, 'word_index': 4}
# {'word': '1.0', 'keyword_vector': array([ 7.807625 , -2.5375545, -1.844668 , -3.1793091], dtype=float32), 'sentence_index': 43, 'word_index': 5}
# {'word': 'K', 'keyword_vector': array([-2.262888, -2.916118,  6.470148, -2.348701], dtype=float32), 'sentence_index': 43, 'word_index': 6}
# {'word': '-', 'keyword_vector': array([ 7.116022 , -2.9110487, -1.1993631, -3.0866992], dtype=float32), 'sentence_index': 43, 'word_index': 7}
# {'word': '3.9', 'keyword_vector': array([ 7.566059 , -2.7210293, -1.5059195, -3.1760542], dtype=float32), 'sentence_index': 43, 'word_index': 8}
# {'word': '2017-06-15', 'keyword_vector': array([ 8.29714  , -2.6157804, -2.4223714, -3.0028694], dtype=float32), 'sentence_index': 44, 'word_index': 0}
# {'word': '02:02PM', 'keyword_vector': array([ 7.5727615, -2.835273 , -1.4124866, -3.2678022], dtype=float32), 'sentence_index': 44, 'word_index': 1}
# {'word': 'BLOOD', 'keyword_vector': array([-0.13178124, -3.3592474 ,  5.2319508 , -3.0293524 ], dtype=float32), 'sentence_index': 44, 'word_index': 2}
# {'word': 'Mg', 'keyword_vector': array([-1.9237574, -2.74966  ,  6.0618615, -2.651683 ], dtype=float32), 'sentence_index': 45, 'word_index': 0}
# {'word': '-', 'keyword_vector': array([ 6.8450675, -2.7693303, -0.9789763, -2.970561 ], dtype=float32), 'sentence_index': 45, 'word_index': 1}
# {'word': '2.1', 'keyword_vector': array([ 7.799538 , -2.518295 , -1.9418955, -3.0298617], dtype=float32), 'sentence_index': 45, 'word_index': 2}
# {'word': 'FINAL', 'keyword_vector': array([ 8.04222  , -2.5065894, -2.5765328, -2.2532609], dtype=float32), 'sentence_index': 46, 'word_index': 0}
# {'word': 'REPORT', 'keyword_vector': array([ 7.9878035, -2.568562 , -2.6556435, -2.102412 ], dtype=float32), 'sentence_index': 46, 'word_index': 1}
# {'word': 'TWO', 'keyword_vector': array([-1.9354064, -3.2174501,  6.456997 , -2.4546525], dtype=float32), 'sentence_index': 47, 'word_index': 0}
# {'word': 'VIEW', 'keyword_vector': array([-2.243011 , -3.289307 ,  6.5711627, -2.130904 ], dtype=float32), 'sentence_index': 47, 'word_index': 1}
# {'word': 'CHEST', 'keyword_vector': array([-2.1785233, -3.1423666,  6.5925827, -2.2753282], dtype=float32), 'sentence_index': 47, 'word_index': 2}
# {'word': ',', 'keyword_vector': array([ 7.95999  , -3.0974731, -1.4126348, -3.2609932], dtype=float32), 'sentence_index': 47, 'word_index': 3}
# {'word': '2017-06-17', 'keyword_vector': array([ 8.279928 , -2.6161277, -2.2973685, -3.1236844], dtype=float32), 'sentence_index': 47, 'word_index': 4}
# {'word': 'COMPARISON', 'keyword_vector': array([ 8.0341835, -2.425859 , -2.6961184, -2.6641958], dtype=float32), 'sentence_index': 48, 'word_index': 0}
# {'word': ':', 'keyword_vector': array([ 8.136511 , -2.4300885, -3.0171154, -2.3924067], dtype=float32), 'sentence_index': 48, 'word_index': 1}
# {'word': '2017-06-14', 'keyword_vector': array([ 8.401082 , -2.5361876, -3.040976 , -2.5036337], dtype=float32), 'sentence_index': 49, 'word_index': 0}
# {'word': '.', 'keyword_vector': array([ 8.402028 , -2.515827 , -2.956544 , -2.5144446], dtype=float32), 'sentence_index': 49, 'word_index': 1}
# {'word': 'INDICATION', 'keyword_vector': array([ 8.0625105, -1.7783014, -3.1167011, -2.6628826], dtype=float32), 'sentence_index': 50, 'word_index': 0}
# {'word': ':', 'keyword_vector': array([ 8.099353 , -1.5594888, -3.3459048, -2.5394802], dtype=float32), 'sentence_index': 50, 'word_index': 1}
# {'word': 'Status', 'keyword_vector': array([ 7.1109076, -2.3080637, -3.2326996, -1.3531189], dtype=float32), 'sentence_index': 51, 'word_index': 0}
# {'word': 'post', 'keyword_vector': array([ 7.6737695, -2.3382614, -3.3510687, -1.1593311], dtype=float32), 'sentence_index': 51, 'word_index': 1}
# {'word': 'coronary', 'keyword_vector': array([-3.2777617, -1.2026834, -2.4275022,  7.320978 ], dtype=float32), 'sentence_index': 51, 'word_index': 2}
# {'word': 'bypass', 'keyword_vector': array([-3.1477644, -1.1341804, -2.486882 ,  7.321186 ], dtype=float32), 'sentence_index': 51, 'word_index': 3}
# {'word': 'surgery', 'keyword_vector': array([-3.0126235, -1.1578753, -2.6467254,  7.231864 ], dtype=float32), 'sentence_index': 51, 'word_index': 4}
# {'word': '.', 'keyword_vector': array([ 7.8887677, -2.5783443, -3.1854544, -1.8094683], dtype=float32), 'sentence_index': 51, 'word_index': 5}
# {'word': 'There', 'keyword_vector': array([ 8.122222 , -2.9598534, -2.484752 , -1.7457951], dtype=float32), 'sentence_index': 52, 'word_index': 0}
# {'word': 'has', 'keyword_vector': array([ 7.9254127, -3.01509  , -2.319497 , -1.8090184], dtype=float32), 'sentence_index': 52, 'word_index': 1}
# {'word': 'been', 'keyword_vector': array([ 7.841183 , -2.7610984, -2.336299 , -2.0231726], dtype=float32), 'sentence_index': 52, 'word_index': 2}
# {'word': 'removal', 'keyword_vector': array([ 6.673537 , -2.8847618, -2.6539247, -1.147119 ], dtype=float32), 'sentence_index': 52, 'word_index': 3}
# {'word': 'of', 'keyword_vector': array([ 7.362656 , -2.8043032, -2.7454586, -1.200161 ], dtype=float32), 'sentence_index': 52, 'word_index': 4}
# {'word': 'a', 'keyword_vector': array([-0.5714905, -2.548008 , -2.8254755,  6.7546105], dtype=float32), 'sentence_index': 52, 'word_index': 5}
# {'word': 'Swan-Ganz', 'keyword_vector': array([-1.954238 , -2.2866054, -2.4820583,  7.6120577], dtype=float32), 'sentence_index': 52, 'word_index': 6}
# {'word': 'catheter', 'keyword_vector': array([-1.9103489, -2.220003 , -2.5861132,  7.4958434], dtype=float32), 'sentence_index': 52, 'word_index': 7}
# {'word': 'and', 'keyword_vector': array([ 7.9357095, -3.0269587, -2.5674047, -1.585813 ], dtype=float32), 'sentence_index': 52, 'word_index': 8}
# {'word': 'placement', 'keyword_vector': array([ 6.802617  , -3.510732  , -2.555821  , -0.14967526], dtype=float32), 'sentence_index': 52, 'word_index': 9}
# {'word': 'of', 'keyword_vector': array([ 7.3214827, -3.059371 , -2.7692037, -0.9264801], dtype=float32), 'sentence_index': 52, 'word_index': 10}
# {'word': 'a', 'keyword_vector': array([-0.7609482, -2.7581844, -2.7717535,  6.978738 ], dtype=float32), 'sentence_index': 52, 'word_index': 11}
# {'word': 'right', 'keyword_vector': array([-1.7870505, -2.5519485, -2.4614372,  7.658143 ], dtype=float32), 'sentence_index': 52, 'word_index': 12}
# {'word': 'internal', 'keyword_vector': array([-1.935027 , -2.4562678, -2.3429046,  7.688109 ], dtype=float32), 'sentence_index': 52, 'word_index': 13}
# {'word': 'jugular', 'keyword_vector': array([-2.01933  , -2.447462 , -2.3240664,  7.749555 ], dtype=float32), 'sentence_index': 52, 'word_index': 14}
# {'word': 'vascular', 'keyword_vector': array([-2.0054824, -2.3629982, -2.4111986,  7.7413507], dtype=float32), 'sentence_index': 52, 'word_index': 15}
# {'word': 'catheter', 'keyword_vector': array([-2.0932844, -2.3390915, -2.3733242,  7.6641517], dtype=float32), 'sentence_index': 52, 'word_index': 16}
# {'word': ',', 'keyword_vector': array([ 7.0431676 , -3.9730468 , -2.6468801 ,  0.02820703], dtype=float32), 'sentence_index': 52, 'word_index': 17}
# {'word': 'with', 'keyword_vector': array([ 7.582258 , -3.2216296, -1.9178216, -2.111756 ], dtype=float32), 'sentence_index': 52, 'word_index': 18}
# {'word': 'the', 'keyword_vector': array([ 6.6365643, -3.941879 , -1.2237391, -1.1555703], dtype=float32), 'sentence_index': 52, 'word_index': 19}
# {'word': 'tip', 'keyword_vector': array([ 6.375528 , -3.8493688, -1.0892618, -1.3757197], dtype=float32), 'sentence_index': 52, 'word_index': 20}
# {'word': 'terminating', 'keyword_vector': array([ 7.6992173, -2.5573468, -2.0876722, -2.947252 ], dtype=float32), 'sentence_index': 52, 'word_index': 21}
# {'word': 'in', 'keyword_vector': array([ 7.776814 , -2.4795828, -2.2457013, -2.6601145], dtype=float32), 'sentence_index': 52, 'word_index': 22}
# {'word': 'the', 'keyword_vector': array([ 7.943797 , -2.6087992, -2.3598876, -2.3570309], dtype=float32), 'sentence_index': 52, 'word_index': 23}
# ...
# {'word': 'no', 'keyword_vector': array([ 7.673343 , -2.244266 , -2.476287 , -2.0648575], dtype=float32), 'sentence_index': 145, 'word_index': 27}
# {'word': 'lifting', 'keyword_vector': array([ 6.872199 , -1.405362 , -1.921699 , -2.7017405], dtype=float32), 'sentence_index': 145, 'word_index': 28}
# {'word': '>', 'keyword_vector': array([ 7.195123 , -0.8442814, -3.2483938, -2.5248985], dtype=float32), 'sentence_index': 145, 'word_index': 29}
# {'word': '10', 'keyword_vector': array([ 7.832392 , -1.1627516, -3.2608693, -2.568702 ], dtype=float32), 'sentence_index': 145, 'word_index': 30}
# {'word': 'for', 'keyword_vector': array([ 7.774802 , -1.3334153, -2.8867722, -2.9897919], dtype=float32), 'sentence_index': 145, 'word_index': 32}
# {'word': '10', 'keyword_vector': array([ 7.8460784, -1.418481 , -3.2421918, -2.7313921], dtype=float32), 'sentence_index': 145, 'word_index': 33}
# {'word': 'weeks', 'keyword_vector': array([ 8.08018  , -1.6767019, -3.081531 , -2.662915 ], dtype=float32), 'sentence_index': 145, 'word_index': 34}
# {'word': 'A.', 'keyword_vector': array([ 8.100506 , -2.16667  , -3.104897 , -2.4304752], dtype=float32), 'sentence_index': 146, 'word_index': 0}
# {'word': 'Instructions', 'keyword_vector': array([ 8.145259 , -2.3972788, -3.0160375, -2.5354722], dtype=float32), 'sentence_index': 146, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.292218 , -2.3184185, -2.944295 , -2.5551112], dtype=float32), 'sentence_index': 146, 'word_index': 2}
# {'word': 'with', 'keyword_vector': array([ 8.038678 , -2.601649 , -2.6997633, -2.4431202], dtype=float32), 'sentence_index': 146, 'word_index': 3}
# {'word': 'Dr.', 'keyword_vector': array([ 8.007984 , -2.317585 , -2.6571198, -2.808206 ], dtype=float32), 'sentence_index': 146, 'word_index': 4}
# {'word': 'Matthew', 'keyword_vector': array([ 7.6478415, -1.9094337, -2.8036206, -2.7681806], dtype=float32), 'sentence_index': 146, 'word_index': 5}
# {'word': 'in', 'keyword_vector': array([ 8.210731 , -2.1126518, -2.8434107, -3.0805113], dtype=float32), 'sentence_index': 146, 'word_index': 6}
# {'word': '2-3', 'keyword_vector': array([ 8.310132 , -2.284166 , -2.8839653, -2.6746113], dtype=float32), 'sentence_index': 146, 'word_index': 7}
# {'word': 'weeks', 'keyword_vector': array([ 8.307828 , -2.2827964, -2.7996812, -2.7512183], dtype=float32), 'sentence_index': 146, 'word_index': 8}
# {'word': 'with', 'keyword_vector': array([ 8.131579 , -2.46041  , -2.8058853, -2.5683687], dtype=float32), 'sentence_index': 146, 'word_index': 9}
# {'word': 'Dr.', 'keyword_vector': array([ 8.0323925, -2.1723783, -2.6370692, -2.8817463], dtype=float32), 'sentence_index': 146, 'word_index': 10}
# {'word': 'Dellinger', 'keyword_vector': array([ 8.152233 , -1.94175  , -3.123981 , -2.7674623], dtype=float32), 'sentence_index': 146, 'word_index': 11}
# {'word': 'in', 'keyword_vector': array([ 8.177146 , -2.091732 , -2.8567634, -3.110665 ], dtype=float32), 'sentence_index': 146, 'word_index': 12}
# {'word': '2-3', 'keyword_vector': array([ 8.280499 , -2.25274  , -2.9054787, -2.7325952], dtype=float32), 'sentence_index': 146, 'word_index': 13}
# {'word': 'weeks', 'keyword_vector': array([ 8.260378 , -2.2207904, -2.8270626, -2.8212063], dtype=float32), 'sentence_index': 146, 'word_index': 14}
# {'word': 'with', 'keyword_vector': array([ 8.113517 , -2.373066 , -2.8760555, -2.598996 ], dtype=float32), 'sentence_index': 146, 'word_index': 15}
# {'word': 'Dr.', 'keyword_vector': array([ 8.060979 , -2.1936636, -2.686397 , -2.8024135], dtype=float32), 'sentence_index': 146, 'word_index': 16}
# {'word': 'les', 'keyword_vector': array([ 8.136994 , -1.8846925, -3.1662889, -2.6576548], dtype=float32), 'sentence_index': 146, 'word_index': 17}
# {'word': 'Gokey', 'keyword_vector': array([ 8.162046 , -2.0705628, -3.1155305, -2.6813233], dtype=float32), 'sentence_index': 146, 'word_index': 18}
# {'word': 'in', 'keyword_vector': array([ 8.165781 , -2.1128054, -2.8607624, -3.044292 ], dtype=float32), 'sentence_index': 146, 'word_index': 19}
# {'word': '4', 'keyword_vector': array([ 8.257743, -2.175952, -2.869318, -2.848975], dtype=float32), 'sentence_index': 146, 'word_index': 20}
# {'word': 'weeks', 'keyword_vector': array([ 8.267468 , -2.1992457, -2.9299796, -2.8552558], dtype=float32), 'sentence_index': 146, 'word_index': 21}
# {'word': 'Curtis', 'keyword_vector': array([ 8.408227 , -2.092247 , -3.0301192, -2.8332062], dtype=float32), 'sentence_index': 147, 'word_index': 0}
# {'word': 'van', 'keyword_vector': array([ 8.42929  , -2.1438255, -2.9593267, -2.8442614], dtype=float32), 'sentence_index': 147, 'word_index': 1}
# {'word': 'den', 'keyword_vector': array([ 8.427405 , -2.1293988, -2.9610965, -2.8430638], dtype=float32), 'sentence_index': 147, 'word_index': 2}
# {'word': 'Moreno', 'keyword_vector': array([ 8.389632 , -2.1823766, -2.8927014, -2.8326209], dtype=float32), 'sentence_index': 147, 'word_index': 3}
# {'word': 'MD', 'keyword_vector': array([ 8.419843 , -2.2633352, -2.8645153, -2.8729174], dtype=float32), 'sentence_index': 147, 'word_index': 4}
# {'word': '07-506', 'keyword_vector': array([ 8.422777 , -2.2734993, -2.8456469, -2.9770339], dtype=float32), 'sentence_index': 147, 'word_index': 5}
# {'word': 'Completed', 'keyword_vector': array([ 8.399623 , -2.1355274, -3.1116092, -2.7637622], dtype=float32), 'sentence_index': 148, 'word_index': 0}
# {'word': 'by', 'keyword_vector': array([ 8.382401 , -2.1124468, -3.0551538, -2.8010762], dtype=float32), 'sentence_index': 148, 'word_index': 1}
# {'word': ':', 'keyword_vector': array([ 8.405141 , -2.1108742, -3.1994653, -2.603381 ], dtype=float32), 'sentence_index': 148, 'word_index': 2}
# {'word': 'Scott', 'keyword_vector': array([ 8.48466  , -2.387701 , -2.8152246, -2.8048365], dtype=float32), 'sentence_index': 149, 'word_index': 0}
# {'word': 'Robert', 'keyword_vector': array([ 8.46585  , -2.306724 , -2.856756 , -2.7299962], dtype=float32), 'sentence_index': 149, 'word_index': 1}
# {'word': 'NP', 'keyword_vector': array([ 8.464736 , -2.3029895, -2.8277285, -2.7174568], dtype=float32), 'sentence_index': 149, 'word_index': 2}
# {'word': '80-AUM', 'keyword_vector': array([ 8.494685 , -2.338442 , -2.8531003, -2.7502725], dtype=float32), 'sentence_index': 149, 'word_index': 3}
# {'word': '2017-06-29', 'keyword_vector': array([ 8.478395 , -2.322336 , -2.8361754, -2.8181171], dtype=float32), 'sentence_index': 149, 'word_index': 4}
# {'word': '@', 'keyword_vector': array([ 8.506925 , -2.3315444, -2.8194058, -2.8489063], dtype=float32), 'sentence_index': 149, 'word_index': 5}
# {'word': '1121', 'keyword_vector': array([ 8.479025 , -2.3590822, -2.8122663, -2.8786626], dtype=float32), 'sentence_index': 149, 'word_index': 6}
# {'word': 'Signed', 'keyword_vector': array([ 8.462224 , -2.1158624, -3.1723435, -2.6392295], dtype=float32), 'sentence_index': 150, 'word_index': 0}
# {'word': 'electronically', 'keyword_vector': array([ 8.452932 , -2.0998125, -3.1410387, -2.691322 ], dtype=float32), 'sentence_index': 150, 'word_index': 1}
# {'word': 'by', 'keyword_vector': array([ 8.450076 , -2.0544348, -3.1470203, -2.7398126], dtype=float32), 'sentence_index': 150, 'word_index': 2}
# {'word': ':', 'keyword_vector': array([ 8.448947 , -2.099598 , -3.1868367, -2.6131577], dtype=float32), 'sentence_index': 150, 'word_index': 3}
# {'word': 'DR.', 'keyword_vector': array([ 8.441731 , -2.4364047, -2.8529868, -2.6150749], dtype=float32), 'sentence_index': 151, 'word_index': 0}
# {'word': 'Barbara', 'keyword_vector': array([ 8.348338 , -2.271411 , -3.0066128, -2.523483 ], dtype=float32), 'sentence_index': 151, 'word_index': 1}
# {'word': 'van', 'keyword_vector': array([ 8.456126 , -2.3518486, -2.9177766, -2.7130182], dtype=float32), 'sentence_index': 151, 'word_index': 2}
# {'word': 'de', 'keyword_vector': array([ 8.443514 , -2.3878548, -2.9416108, -2.6504548], dtype=float32), 'sentence_index': 151, 'word_index': 3}
# {'word': 'Tate', 'keyword_vector': array([ 8.421195 , -2.312785 , -3.0045931, -2.6702607], dtype=float32), 'sentence_index': 151, 'word_index': 4}
# {'word': 'on', 'keyword_vector': array([ 8.389733 , -2.361309 , -2.9969144, -2.7502294], dtype=float32), 'sentence_index': 151, 'word_index': 5}
# {'word': ':', 'keyword_vector': array([ 8.437367 , -2.416616 , -2.8581219, -2.7371268], dtype=float32), 'sentence_index': 151, 'word_index': 6}
# {'word': 'FRI', 'keyword_vector': array([ 8.405491 , -2.1897013, -3.0559459, -2.7845082], dtype=float32), 'sentence_index': 152, 'word_index': 0}
# {'word': '2017-07-28', 'keyword_vector': array([ 8.400282 , -2.2153506, -2.9756637, -2.8651567], dtype=float32), 'sentence_index': 152, 'word_index': 1}
# {'word': '1:55', 'keyword_vector': array([ 8.418858 , -2.2241828, -2.9906123, -2.8648837], dtype=float32), 'sentence_index': 152, 'word_index': 2}
# {'word': 'PM', 'keyword_vector': array([ 8.4061575, -2.3403952, -2.9305713, -2.8533814], dtype=float32), 'sentence_index': 152, 'word_index': 3}
# {'word': '(', 'keyword_vector': array([ 8.384631 , -2.5039907, -2.7423506, -2.5451095], dtype=float32), 'sentence_index': 153, 'word_index': 0}
# {'word': 'End', 'keyword_vector': array([ 8.226531 , -2.2320921, -2.8923464, -2.8302648], dtype=float32), 'sentence_index': 153, 'word_index': 1}
# {'word': 'of', 'keyword_vector': array([ 8.346241 , -2.1538188, -2.9156218, -2.755864 ], dtype=float32), 'sentence_index': 153, 'word_index': 2}
# {'word': 'Report', 'keyword_vector': array([ 8.328031 , -2.283342 , -2.8908486, -2.7215567], dtype=float32), 'sentence_index': 153, 'word_index': 3}
# {'word': ')', 'keyword_vector': array([ 8.420274 , -2.1988072, -2.9391904, -2.7502644], dtype=float32), 'sentence_index': 153, 'word_index': 4}
#   3%|██▏                                                                                | 2/74 [00:10<06:26,  5.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-03521c1184a2> in <module>
#      13     positions = create_pos_dict(file_concepts)
#      14
# ---> 15     word_list = utility.process_string_finetune(line,0)
#      16
#      17     for entry in word_list:
#
# ~\Documents\CS 6120 Project\CS6120\Code\BERT_utility.py in process_string_finetune(self, string_input, padding_length)
#      86             input_ids = torch.tensor(encodings).long().unsqueeze(0)
#      87
# ---> 88             outputs = self.bert_model(input_ids,token_type_ids=None)
#      89
#      90             bert_vector = outputs
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1516             output_attentions=output_attentions,
#    1517             output_hidden_states=output_hidden_states,
# -> 1518             return_dict=return_dict,
#    1519         )
#    1520
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, output_attentions, output_hidden_states, return_dict)
#     839             output_attentions=output_attentions,
#     840             output_hidden_states=output_hidden_states,
# --> 841             return_dict=return_dict,
#     842         )
#     843         sequence_output = encoder_outputs[0]
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions, output_hidden_states, return_dict)
#     480                     encoder_hidden_states,
#     481                     encoder_attention_mask,
# --> 482                     output_attentions,
#     483                 )
#     484             hidden_states = layer_outputs[0]
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions)
#     421
#     422         layer_output = apply_chunking_to_forward(
# --> 423             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     424         )
#     425         outputs = (layer_output,) + outputs
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    1694         return torch.cat(output_chunks, dim=chunk_dim)
#    1695
# -> 1696     return forward_fn(*input_tensors)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in feed_forward_chunk(self, attention_output)
#     428     def feed_forward_chunk(self, attention_output):
#     429         intermediate_output = self.intermediate(attention_output)
# --> 430         layer_output = self.output(intermediate_output, attention_output)
#     431         return layer_output
#     432
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\transformers\modeling_bert.py in forward(self, hidden_states, input_tensor)
#     367
#     368     def forward(self, hidden_states, input_tensor):
# --> 369         hidden_states = self.dense(hidden_states)
#     370         hidden_states = self.dropout(hidden_states)
#     371         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
for file in tqdm(os.listdir(partners_file_path+r'\txt')):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(partners_file_path+r'\txt', file)
    file_name = file.strip(".txt")
    oFile = open(file_path, 'r')
    line = oFile.read()
    all_lines = line.split("\n")
    file_concepts = concept_df[(concept_df['file_name']==file_name)&(concept_df['source']=='partners')]
    positions = create_pos_dict(file_concepts)
    
    word_list = utility.process_string_finetune(line,0)
    
    for entry in word_list:
        key = str(entry['sentence_index'])+ ":" +str(entry['word_index'])
        if(key in positions):
            entry.update({"concept":positions[key]})
        else:
            entry.update({"concept":"blank"})
    
    all_words_list.extend(word_list)

# %%
len(all_words_list)

# %%
words_df = pd.DataFrame(all_words_list)

# %%
set(list(words_df['concept']))

# %%
test_dict = {"a":"1", "b":"2"}

# %%
if("a" in test_dict):
    print(test_dict["a"])

# %%
X = np.vstack(list(words_df["keyword_vector"]))                                
y = words_df["concept"]

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0,solver="lbfgs").fit(X, y)

# %%
clf.score(X,y)

# %%
test_data_file_path = os.path.dirname(os.getcwd()) + r'\Data\reference_standard_for_test_data' 

list_of_all_test_concepts = list()

for file in os.listdir(test_data_file_path+r'\concepts'):
    file_path = os.path.join(test_data_file_path+r'\concepts', file)
    list_of_all_test_concepts.extend(get_concepts_from_file(file_path,file.strip(".con"),'test_data'))

# %%
test_concept_df = pd.DataFrame(list_of_all_test_concepts)

# %%
test_concept_df.head()

# %%
all_words_list_test = list()
test_data_texts_path =  os.path.dirname(os.getcwd()) + r'\Data\test_data'
for file in tqdm(os.listdir(test_data_texts_path)):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(test_data_texts_path, file)
    
    file_name = file.strip(".txt")
    
    oFile = open(file_path, 'r')
    
    line = oFile.read()
    
    all_lines = line.split("\n")
    
    file_concepts = test_concept_df[(test_concept_df['file_name']==file_name)&(test_concept_df['source']=='test_data')]
    
    positions = create_pos_dict(file_concepts)
    
    word_list = process_string_finetune(line,0)
    
    for entry in word_list:
        key = str(entry['sentence_index'])+ ":" +str(entry['word_index'])
        if(key in positions):
            entry.update({"concept":positions[key]})
        else:
            entry.update({"concept":"blank"})
    
    all_words_list_test.extend(word_list)

# %%
test_word_df = pd.DataFrame(all_words_list_test)

# %%
X_test = np.vstack(list(test_word_df["keyword_vector"]))                                
y_test = test_word_df["concept"]

# %%
clf.score(X_test,y_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_true,y_predict,labels)

# %%
y_true = y_test
y_predict = clf.predict(X_test)

# %%
labels = ['blank', 'problem', 'test', 'treatment']

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_true, y_predict, average='macro')

# %%
class_map = {"blank":0,"problem":1,"test":2,"treatment":3}

# %%
encoding_list = list()
label_list = list()
utility = BERT_utility()

for file in tqdm(os.listdir(beth_file_path+r'\txt')):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(beth_file_path+r'\txt', file)
    file_name = file.strip(".txt")
    oFile = open(file_path, 'r')
    line = oFile.read()
    all_lines = line.split("\n")
    file_concepts = concept_df[(concept_df['file_name']==file_name)&(concept_df['source']=='beth')]
    positions = create_pos_dict(file_concepts)
    
    prior_sentence_index = -1
    
    word_list, encoding = utility.process_string_finetune(line,0)
    
    for i in range(len(all_lines)):
        labels = [0] * len(encoding[i])
        fil_word_list = [word for word in word_list if word["sentence_index"]==i+1] 
        for entry in fil_word_list:
            key = str(entry['sentence_index'])+ ":" +str(entry['word_index'])
            if(key in positions):
                for token_position in entry["bert_token_positions"]:
                    labels[token_position] = class_map[positions[key]]
        label_list.append(labels)
    
    encoding_list.extend(encoding)

for file in tqdm(os.listdir(partners_file_path+r'\txt')):
    if(not file.endswith(".txt")):
        continue
    file_path = os.path.join(partners_file_path+r'\txt', file)
    file_name = file.strip(".txt")
    oFile = open(file_path, 'r')
    line = oFile.read()
    all_lines = line.split("\n")
    file_concepts = concept_df[(concept_df['file_name']==file_name)&(concept_df['source']=='partners')]
    positions = create_pos_dict(file_concepts)
    
    prior_sentence_index = -1
    
    word_list, encoding = utility.process_string_finetune(line,0)
    
    for i in range(len(all_lines)):
        labels = [0] * len(encoding[i])
        
        fil_word_list = [word for word in word_list if word["sentence_index"]==i+1] 
        for entry in fil_word_list:
            key = str(entry['sentence_index'])+ ":" +str(entry['word_index'])
            if(key in positions):
                for token_position in entry["bert_token_positions"]:
                    labels[token_position] = class_map[positions[key]]
        label_list.append(labels)
    
    encoding_list.extend(encoding)

# %%
[0]*5

# %%
tokenizer.convert_ids_to_tokens([101, 2381, 1997, 2556, 7355, 1024, 102])

# %%
label_list[87]

# %%
encoding_list[87]

# %%
len(encoding_list)

# %%
import pickle

# %%
pickle.dump(encoding_list,open("C:/Users/itsma/Documents/CS 6120 Project/input_ids.pkl","wb"))
pickle.dump(label_list,open("C:/Users/itsma/Documents/CS 6120 Project/label.pkl","wb"))

# %%
finetuned_model = pickle.load(open("C:/Users/itsma/Documents/CS 6120 Project/CS6120/Model/finetuned_model.pkl","rb"))

# %%
encodings = tokenizer.encode("Hello, my dog is cute",add_special_tokens = True)

# %%
finetuned_model.cpu()

# %%
input_ids = torch.tensor(encodings).long().unsqueeze(0)
        
outputs = finetuned_model(input_ids,token_type_ids=None)

# %%
filt = [entry for entry in label_list if 3 in entry]
